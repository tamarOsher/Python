# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/61.0 kB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.6 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.3/11.6 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/11.6 MB 2.0 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/11.6 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/11.6 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.6 MB 3.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/11.6 MB 3.8 MB/s eta 0:00:03
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'כיתה': ['ח3', 'ח2', 'ח1'],
        'ממוצע': ['85 ', '90', '87']}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם כיתה ממוצע
# 0    אליז   ח3   85
# 1  בת שבע   ח2    90
# 2    גליה   ח1    87

# %%
sample.appand()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8504\3499898727.py in ?()
# ----> 1 sample.appand()
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'appand'

# %%
sample.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8504\3849401215.py in ?()
# ----> 1 sample.append()
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
sample.insert("ghujk", "Age", 92)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8504\2021178329.py in ?()
# ----> 1 sample.insert("ghujk", "Age", 92)
#
# C:\Python310\lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5143         if not allow_duplicates and column in self.columns:
#    5144             # Should this be a different kind of error??
#    5145             raise ValueError(f"cannot insert {column}, already exists")
#    5146         if not is_integer(loc):
# -> 5147             raise TypeError("loc must be int")
#    5148         # convert non stdlib ints to satisfy typing checks
#    5149         loc = int(loc)
#    5150         if isinstance(value, DataFrame) and len(value.columns) > 1:
#
# TypeError: loc must be int

# %%
other_df = pd.read_csv('cars.csv', usecols=['שם'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 other_df = pd.read_csv('cars.csv', usecols=['שם'])
#
# File C:\Python310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
sample['שם']
# Out:
# 0      אליז
# 1    בת שבע
# 2      גליה
# Name: שם, dtype: object

# %%
sample[sample['כיתה'] =='ח1']
# Out:
#      שם כיתה ממוצע
# 2  גליה   ח1    87

# %%
sample['ממוצע'].max()
# Out:
# '90'

# %%
sample.loc[len(sample.index)]=["fvbg","fv",95]

# %%
sample
# Out:
#        שם כיתה ממוצע
# 0    אליז   ח3   85
# 1  בת שבע   ח2    90
# 2    גליה   ח1    87
# 3    fvbg   fv    95
